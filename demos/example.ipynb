# %%
# %cd ..
# Out:
# /home/nils/NILS/Master/DL2/DL2-ZeroVis

# %%
from src.fromage_inf.inf_utils import PromptParser

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
parser = PromptParser("src/fromage_inf/fromage_model/",
                      "src/fromage_inf/fromage_model/visual_embs.pt")
# Out:
# Using facebook/opt-6.7b for the language model.
# Freezing the LM.
# Initializing embedding for the retrieval token [RET] (id = 50266).

# %%
prompt = {
    "inputs": [
        "Apple CEO"
        # "{CEOs/bill_gates} is the CEO of the company {companies/microsoft} .",
        # "{CEOs/mark_zuckerberg} is the CEO of the company {companies/facebook} .",
        # "{CEOs/jeff_bezos} is the CEO of the company {companies/amazon} .",
        # "{CEOs/elon_musk} is the CEO of the company {companies/tesla} .",
        # "{CEOs/steve_jobs} is the CEO of the company:"
    ],
    "expected_output": "Apple"
}

# Prompt can be path to json, e.g. 'res/example.json'
parser(prompt, root='./', max_img_per_ret=3)
# Out:
# Input conversation:
# Apple CEO [RET]
# Expectation: Apple
# Prediction:
