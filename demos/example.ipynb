# %%
# %cd ..
# Out:
# /home/nils/NILS/Master/DL2/DL2-ZeroVis

# %%
from src.fromage_inf.inf_utils import PromptParser

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
parser = PromptParser("src/fromage_inf/fromage_model/",
                      "src/fromage_inf/fromage_model/visual_embs.pt")
# Out:
# Using facebook/opt-6.7b for the language model.
# Freezing the LM.
# Initializing embedding for the retrieval token [RET] (id = 50266).

# %%
prompt = {
    "inputs": [
        "Bill Gates {CEOs/bill_gates} Microsoft {companies/microsoft}",
        "Mark Zuckerberg {CEOs/mark_zuckerberg} Facebook {companies/facebook}",
        "Jeff Bezos {CEOs/jeff_bezos} Amazon {companies/amazon}",
        "Elon Musk {CEOs/elon_musk} Tesla {companies/tesla}",
        "Steve Jobs {CEOs/steve_jobs} Apple"
    ],
    "expected_output": "Apple"
}

# Prompt can be path to json, e.g. 'res/example.json'
parser(prompt, root='./', max_img_per_ret=3)
# Out:
# Input conversation:
# Bill Gates
# Microsoft
# Mark Zuckerberg
# Facebook
# Jeff Bezos
# Amazon
# Elon Musk
# Tesla
# Steve Jobs
# Apple [RET]
# Expectation: Apple
# Prediction:
